# %% [markdown]
# # Line

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.plot(x, y)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
