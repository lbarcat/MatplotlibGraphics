# %% [markdown]
# # Network

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Cria o grafo
G = nx.Graph()

# Adiciona arestas e nós
G.add_edges_from([(1, 2), (1, 3), (2, 3), (2, 4), (3, 4)])

# Desenha o gráfico
nx.draw_networkx(G, with_labels=True)
plt.show()
